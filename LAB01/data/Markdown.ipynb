# %% [markdown]
# # Perdorimi i Markdown ne JupyterLab

# %% [markdown]
# ## Qellimi
# Qellimi i ketij markdown eshte te mesohet perdorimi i Markdown per formatimin e tekstit ne Jupyter Notebook.

# %% [markdown]
# ## Bazat
# Markdown eshte nje menyre e thjeshte per te formatuar tekst.
#
# - Tituj
# - Bold dhe italic
# - Lista
# - Linke

# %% [markdown]
# ## **Vende per te vizituar**
# 1. Paris
# 2. Roma
# 3. New York
# 4. Tokyo
# 5. Barcelona

# %% [markdown]
# ## Mjetet qe perdoren
# - JupyterLab
# - Miniconda
# - Notebook

# %% [markdown]
# # Analiza e Punes:
# ### Tituj
# # Titull
# ## Nentitull
#
# ### Bold dhe italic
# **bold**
# *italic*
#
# ### Lista
# - Element 1
# - Element 2
# ### Tabele te Dhenash
#
# ### Formula Matematikore

# %% [markdown]
# ----------------------------------

# %% [markdown]
# ## *Filma te famshem*
# - Titanic
# - Avatar
# - The Godfather
# - Inception
# - The Dark Knight

# %% [markdown]
# ## ***Sporte te Njohura***
# 1. Futboll
# 2. Basketboll
# 3. Tenis
# 4. Volejboll

# %% [markdown]
# ## ~Libra te njohur~
# - Harry Potter
# - The Lord Of The Rings
# - To Kill a Mockingbird
# - 1984
# - The Great Gatsby

# %% [markdown]
# --------------------------------------------------------

# %% [markdown]
# | Emri   | Mosha |
# |--------|-------|
# | Ana    |  17   |
# | Ada    |  20   |
# | Deni   |  18   |
# | Nela   |  21   |
# | Kela   |  16   |
# | Mateo  |  19   |
# | Ola    |  20   |

# %% [markdown]
# -----------------------------------------------------------

# %% [markdown]
# ### $ a^2 + b^2 = c^2 $

# %% [markdown]
# ## $$
# x^2
# \sqrt{x}
# \sqrt[n]{x}
# $$

# %% [markdown]
# ## $\frac{a}{b}$

# %% [markdown]
# ## $\sum_{i=1}^{n} i $

# %% [markdown]
# ## $ \int_{a}^{b} x^2 \, dx $

# %% [markdown]
# # $\infty$

# %% [markdown]
# ## $\lim_{x \to0} \frac{\sin x}{x}$

# %% [markdown]
# ## $\frac{d}{dx} x^2 $

# %% [markdown]
# ### $$
# \begin{bmatrix}
# 1 & 2 \\
# 3 & 4
# \end{bmatrix}
# $$

# %%
^
